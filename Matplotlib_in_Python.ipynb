# %% [markdown]
# <a href="https://colab.research.google.com/github/GithubPython7Eduard/Python-Library/blob/main/Matplotlib_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Matplotlib is a low-level graph plotting library in python that serves as a visualization utility:

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
# linspace function
x = np.linspace(0, 10, 100)

# %%
y = np.sin(x)
z = np.cos(x)

# %%
print(x)
print(y)
print(z)
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
#   7.87878788  7.97979798  8.08080808  8.18181818  8.28282828  8.38383838
#   8.48484848  8.58585859  8.68686869  8.78787879  8.88888889  8.98989899
#   9.09090909  9.19191919  9.29292929  9.39393939  9.49494949  9.5959596
#   9.6969697   9.7979798   9.8989899  10.        ]
# [ 0.          0.10083842  0.20064886  0.2984138   0.39313661  0.48385164
#   0.56963411  0.64960951  0.72296256  0.78894546  0.84688556  0.8961922
#   0.93636273  0.96698762  0.98775469  0.99845223  0.99897117  0.98930624
#   0.96955595  0.93992165  0.90070545  0.85230712  0.79522006  0.73002623
#   0.65739025  0.57805259  0.49282204  0.40256749  0.30820902  0.21070855
#   0.11106004  0.01027934 -0.09060615 -0.19056796 -0.28858706 -0.38366419
#  -0.47483011 -0.56115544 -0.64176014 -0.7158225  -0.7825875  -0.84137452
#  -0.89158426 -0.93270486 -0.96431712 -0.98609877 -0.99782778 -0.99938456
#  -0.99075324 -0.97202182 -0.94338126 -0.90512352 -0.85763861 -0.80141062
#  -0.73701276 -0.66510151 -0.58640998 -0.50174037 -0.41195583 -0.31797166
#  -0.22074597 -0.12126992 -0.0205576   0.0803643   0.18046693  0.27872982
#   0.37415123  0.46575841  0.55261747  0.63384295  0.7086068   0.77614685
#   0.83577457  0.8868821   0.92894843  0.96154471  0.98433866  0.99709789
#   0.99969234  0.99209556  0.97438499  0.94674118  0.90944594  0.86287948
#   0.8075165   0.74392141  0.6727425   0.59470541  0.51060568  0.42130064
#   0.32770071  0.23076008  0.13146699  0.03083368 -0.07011396 -0.17034683
#  -0.26884313 -0.36459873 -0.45663749 -0.54402111]
# [ 1.          0.99490282  0.97966323  0.95443659  0.91948007  0.87515004
#   0.8218984   0.76026803  0.69088721  0.61446323  0.53177518  0.44366602
#   0.35103397  0.25482335  0.15601496  0.0556161  -0.04534973 -0.14585325
#  -0.24486989 -0.34139023 -0.43443032 -0.52304166 -0.60632092 -0.68341913
#  -0.75355031 -0.81599952 -0.87013012 -0.91539031 -0.95131866 -0.97754893
#  -0.9938137  -0.99994717 -0.9958868  -0.981674   -0.95745366 -0.92347268
#  -0.88007748 -0.82771044 -0.76690542 -0.69828229 -0.6225406  -0.54045251
#  -0.45285485 -0.36064061 -0.26474988 -0.16616018 -0.06587659  0.03507857
#   0.13567613  0.23489055  0.33171042  0.4251487   0.51425287  0.59811455
#   0.67587883  0.74675295  0.8100144   0.86501827  0.91120382  0.94810022
#   0.97533134  0.99261957  0.99978867  0.99676556  0.98358105  0.96036956
#   0.9273677   0.88491192  0.83343502  0.77346177  0.70560358  0.63055219
#   0.54907273  0.46199582  0.37020915  0.27464844  0.17628785  0.07613012
#  -0.0248037  -0.12548467 -0.2248864  -0.32199555 -0.41582217 -0.50540974
#  -0.58984498 -0.66826712 -0.7398767  -0.8039437  -0.859815   -0.90692104
#  -0.94478159 -0.97301068 -0.99132055 -0.99952453 -0.99753899 -0.98538417
#  -0.96318398 -0.93116473 -0.88965286 -0.83907153]

# %%
# sine wave 
plt.plot(x,y)
plt.show()

# %% [markdown]
# Plotting Without Line

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# Multiple Points

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Matplotlib Markers

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, '*')
plt.show()

# %% [markdown]
# Matplotlib Line

# %%
# Use a dotted line:
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
# Use a dashed line:
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dashed')
plt.show()

# %%
# linestyle can be written as ls
# dotted can be written as :

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, ls = ':')
plt.show()

# %% [markdown]
# Matplotlib Labels and Title

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])

y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
# add plot title and labels for the x- and y-axis:

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
# Out:
# Text(0, 0.5, 'Calorie Burnage')

# %%
# Set font properties for the title and labels:

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %% [markdown]
# Position the Title

# %%
# Position the title to the left:

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.show()

# %% [markdown]
# Matplotlib Grid

# %%
# Add grid lines to the plot:

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calories Burange")

plt.plot(x, y)

plt.grid()

plt.show()

# %% [markdown]
# Specify Which Grid Lines to Display

# %%
# display only grid lines for the x-axis:

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports wath Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x,y)

plt.grid(axis='x')

plt.show()

# %%
# Display only grid lines for the y-axis:

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x,y)

plt.grid(axis='y')

plt.show()

# %% [markdown]
# Matplotlib Subplot

# %%
# Draw 2 plots:

# plot 1:

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

# plot 2:

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)

plt.plot(x,y)

plt.show()

# %%
# Draw 2 plots on top of each other:

# plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

# plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
# Draw 6 plots:

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %% [markdown]
# Title

# %%
# 2 plots, with titles:

# plot 1:

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

# plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.show()

# %% [markdown]
# Super Title

# %%
# add a title for the entire figure

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %% [markdown]
# Matplotlib Scatter

# %%
# A simple scatter plot:

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x,y)
plt.show()

# %% [markdown]
# Compare Plots

# %%
# Draw two plots on the same figure:

# day 1, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y)

# day 2, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %% [markdown]
# Colors

# %%
# Set your own color of the markers:

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %% [markdown]
# Color Map

# %%
# Create a color array, and specify a colormap in the scatter plot:

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c = colors, cmap = 'viridis')

plt.show()

# %%
# include the actual colormap:

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %% [markdown]
# Size

# %%
# Set your own size for the markers:

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

plt.show()

# %% [markdown]
# Matplotlib Bars

# %%
# Draw 4 bars
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
# Three lines to make our compiler able to draw:
import sys
import matplotlib
matplotlib.use('AGG')

import matplotlib.pyplot as plt
import numpy as np

x = ["APPLES", "BANANAS"]
y = [400, 350]

plt.bar(x,y)
plt.show()

# %% [markdown]
# Horizontal Bars

# %%
# Draw 4 horizontal bars:

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x,y)
plt.show()

# %% [markdown]
# Bar Color

# %%
# Draw 4 red bars:

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y, color = 'red')
plt.show()

# %% [markdown]
# Bar Width

# %%
# Draw 4 very thin bars:

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, width = 0.1)
plt.show()

# %% [markdown]
# Bar Height

# %%
# Draw 4 very thin bars:

import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y, height = 0.1)
plt.show()

# %% [markdown]
# Matplotlib Histograms

# %%
# A Normal Data Distribution by NumPy:

import numpy as np

x = np.random.normal(170, 10, 250)

print(x)
# Out:
# [171.95020273 156.72927858 162.36047763 152.17112652 181.07387779
#  166.30286251 164.35974626 147.69249552 167.09526059 177.89380495
#  187.2032093  180.64638013 167.73611812 177.01272323 172.0858815
#  167.1710873  167.37337276 175.74354423 160.32938874 172.16346199
#  170.91820024 182.12332518 162.99736638 180.49776656 155.71946896
#  169.56911999 172.36049628 164.13461175 181.79068426 168.52823007
#  165.28253736 161.19224908 177.02428694 157.64672231 173.26925782
#  193.27335287 163.24727376 163.75678237 188.09770256 160.12049256
#  164.61627953 181.93295509 175.23880483 169.37527545 170.8491306
#  169.64057448 169.53820896 177.78952801 174.19516011 165.47655172
#  176.56924078 177.72419793 160.16645773 174.82390741 167.12937164
#  182.50413406 173.5050103  168.95563863 168.86660754 150.98391744
#  154.00018199 180.65664812 169.91093323 169.81666588 180.17006285
#  160.94226908 152.36643306 162.78930725 158.53999405 167.50014893
#  166.25469632 175.86106322 180.81943782 159.22250596 167.28212432
#  191.40151568 172.80261814 162.84084604 178.55567752 166.96371695
#  174.06868766 160.06101414 167.41232937 145.49262277 176.19342
#  157.50704467 145.86830254 176.67892039 162.10649944 156.40154079
#  174.19140352 191.32040887 174.55793563 164.48093284 167.95989701
#  166.65505982 188.80797835 179.50674379 175.29498914 170.55578633
#  163.97064247 160.79638366 158.5289339  161.35090669 170.89109037
#  180.37725858 177.30825463 177.37807493 177.50239372 176.48401192
#  176.63175961 168.57081087 179.6122968  174.43169228 159.47978769
#  179.66773749 169.71715761 183.98214035 170.97555725 178.66486966
#  171.63809924 174.24933012 187.2546433  161.02044246 170.63916808
#  155.51084829 168.39343376 168.37679182 177.74995304 164.42044
#  166.7888972  162.40373603 163.94751559 167.0944946  169.02940535
#  187.69124775 172.44013392 181.70209624 179.75307112 159.30760006
#  177.01430225 168.84393396 168.31652604 189.09649165 165.83854567
#  192.18247072 155.735129   158.328878   169.44955087 171.74857489
#  182.52267269 167.71593235 166.55338913 167.91188434 158.48448188
#  160.72962736 158.79930145 175.74571285 174.24967636 159.25023437
#  194.56569471 162.61965064 177.61512553 171.45765906 166.19856397
#  180.40896368 167.6763068  169.08163517 162.50473155 164.00187081
#  160.44819358 162.4629762  173.09962101 163.03728697 162.36142637
#  156.67484475 176.32573871 150.67878011 174.97323412 192.28073723
#  165.99880747 182.59588324 144.47262625 174.72481116 196.65730911
#  173.37056877 155.49820775 161.57507923 179.52472612 164.34094886
#  185.3118962  185.3046548  160.31766791 168.02006259 165.97955646
#  166.77488728 165.41303999 169.33253652 165.8855242  166.09576318
#  173.03233592 188.98832411 164.41222939 176.31532482 161.60024892
#  180.31168579 166.16335469 158.55642519 168.76475946 182.30087355
#  164.92972721 169.17607369 181.11891746 171.51198466 178.19648995
#  157.19362954 156.42770452 192.80751816 183.35522957 170.21031064
#  159.75673919 163.98570336 179.30284191 180.45733065 165.17949046
#  163.93152512 175.84816481 191.84132168 164.02263581 174.4489963
#  165.35338805 163.02032865 173.79582562 176.74513328 151.96877381
#  175.51644835 174.68236046 171.24916022 148.0563253  175.65669878
#  172.00436794 149.12729251 172.06158143 170.77794247 181.49469981
#  186.39823878 175.67182286 153.26719186 170.59357524 168.23705478]

# %%
# A simple histogram

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %% [markdown]
# Matplotlib Pie Charts

# %%
# A simple pie chart:

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %% [markdown]
# Matplotlib Pie Chart Labels

# %%
# A simple Pie Chart:

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
# Start the first wedge at 90 degrees:

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()
